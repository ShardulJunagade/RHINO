# %%
import os

class_mapping = {0: "CFCBK", 1: "FCBK", 2: "Zigzag"}
image_width = 2560
image_height = 2560

# %%
def convert_to_dota_format(input_path, output_path):
	with open(input_path, "r") as infile, open(output_path, "w") as outfile:
		for line in infile:
			# Split the annotation line into its components
			values = line.strip().split()
			class_id = int(values[0])  # First value is the class ID
			coordinates = list(map(float, values[1:9]))  # Next 8 values are normalized coordinates

			# Denormalize the coordinates to absolute pixel values
			denormalized_coords = [
				int(coordinates[i] * (image_width if i % 2 == 0 else image_height)) + 0.0
				for i in range(8)
			]

			# Retrieve the class name from the mapping
			class_name = class_mapping.get(class_id, "UNKNOWN")

			# Format the line in DOTA format
			dota_line = " ".join(map(str, denormalized_coords)) + f" {class_name} 0\n"
			outfile.write(dota_line)

def process_folder(input_folder, output_folder):
	os.makedirs(output_folder, exist_ok=True)
	for file_name in os.listdir(input_folder):
		if file_name.endswith(".txt"):
			input_path = os.path.join(input_folder, file_name)
			output_path = os.path.join(output_folder, file_name)
			convert_to_dota_format(input_path, output_path)
			print(f"Converted {file_name} to DOTA format.")

# %%
# convert_to_dota_format("./test.txt", "./test_dota.txt")

# %%
input_folder = "../data/swinir/haryana_same_class_count_10_120_1000_4x/labels"
output_folder = "../data/swinir/haryana_same_class_count_10_120_1000_4x/annfiles"
process_folder(input_folder, output_folder)
# Out:
# Converted 8556974_3412452.txt to DOTA format.
# Converted 8584492_3544535.txt to DOTA format.
# Converted 8353346_3483997.txt to DOTA format.
# Converted 8540464_3346410.txt to DOTA format.
# Converted 8537712_3492252.txt to DOTA format.
# Converted 8567981_3561045.txt to DOTA format.
# Converted 8518450_3274865.txt to DOTA format.
# Converted 8334084_3475742.txt to DOTA format.
# Converted 8543216_3489500.txt to DOTA format.
# Converted 8551471_3412452.txt to DOTA format.
# Converted 8482678_3437217.txt to DOTA format.
# Converted 8474422_3461983.txt to DOTA format.
# Converted 8543216_3316141.txt to DOTA format.
# Converted 8573485_3561045.txt to DOTA format.
# Converted 8317574_3492252.txt to DOTA format.
# Converted 8554223_3351914.txt to DOTA format.
# Converted 8556974_3417955.txt to DOTA format.
# Converted 8581740_3489500.txt to DOTA format.
# Converted 8589995_3530776.txt to DOTA format.
# Converted 8614761_3277617.txt to DOTA format.
# Converted 8551471_3371176.txt to DOTA format.
# Converted 8449657_3417955.txt to DOTA format.
# Converted 8317574_3495004.txt to DOTA format.
# Converted 8477174_3261106.txt to DOTA format.
# Converted 8523954_3371176.txt to DOTA format.
# Converted 8468919_3461983.txt to DOTA format.
# Converted 8490933_3343658.txt to DOTA format.
# Converted 8543216_3360169.txt to DOTA format.
# Converted 8477174_3445473.txt to DOTA format.
# Converted 8512947_3376679.txt to DOTA format.
# Converted 8512947_3379431.txt to DOTA format.
# Converted 8515698_3459231.txt to DOTA format.
# Converted 8430395_3445473.txt to DOTA format.
# Converted 8474422_3236341.txt to DOTA format.
# Converted 8518450_3376679.txt to DOTA format.
# Converted 8507443_3387686.txt to DOTA format.
# Converted 8554223_3373928.txt to DOTA format.
# Converted 8559726_3365672.txt to DOTA format.
# Converted 8584492_3563797.txt to DOTA format.
# Converted 8477174_3354665.txt to DOTA format.
# Converted 8540464_3294127.txt to DOTA format.
# Converted 8493684_3456480.txt to DOTA format.
# Converted 8595499_3558294.txt to DOTA format.
# Converted 8501940_3428962.txt to DOTA format.
# Converted 8427643_3382183.txt to DOTA format.
# Converted 8314822_3486749.txt to DOTA format.
# Converted 8490933_3470238.txt to DOTA format.
# Converted 8540464_3329900.txt to DOTA format.
# Converted 8554223_3368424.txt to DOTA format.
# Converted 8397374_3401445.txt to DOTA format.
# Converted 8471671_3464735.txt to DOTA format.
# Converted 8559726_3368424.txt to DOTA format.
# Converted 8504691_3349162.txt to DOTA format.
# Converted 8598250_3519769.txt to DOTA format.
# Converted 8592747_3233589.txt to DOTA format.
# Converted 8576236_3475742.txt to DOTA format.
# Converted 8534960_3316141.txt to DOTA format.
# Converted 8416636_3398693.txt to DOTA format.
# Converted 8587243_3236341.txt to DOTA format.
# Converted 8534960_3365672.txt to DOTA format.
# Converted 8554223_3461983.txt to DOTA format.
# Converted 8320325_3475742.txt to DOTA format.
# Converted 8479926_3373928.txt to DOTA format.
# Converted 8430395_3373928.txt to DOTA format.
# Converted 8342339_3481245.txt to DOTA format.
# Converted 8496436_3296879.txt to DOTA format.
# Converted 8537712_3340907.txt to DOTA format.
# Converted 8523954_3439969.txt to DOTA format.
# Converted 8521202_3327148.txt to DOTA format.
# Converted 8589995_3508762.txt to DOTA format.
# Converted 8499188_3340907.txt to DOTA format.
# Converted 8490933_3373928.txt to DOTA format.
# Converted 8413884_3335403.txt to DOTA format.
# Converted 8532209_3448224.txt to DOTA format.
# Converted 8551471_3360169.txt to DOTA format.
# Converted 8411132_3382183.txt to DOTA format.
# Converted 8548719_3464735.txt to DOTA format.
# Converted 8512947_3483997.txt to DOTA format.
# Converted 8452408_3365672.txt to DOTA format.
# Converted 8623016_3244596.txt to DOTA format.
# Converted 8499188_3373928.txt to DOTA format.
# Converted 8482678_3296879.txt to DOTA format.
# Converted 8518450_3351914.txt to DOTA format.
# Converted 8490933_3428962.txt to DOTA format.
# Converted 8548719_3401445.txt to DOTA format.
# Converted 8562478_3406948.txt to DOTA format.
# Converted 8559726_3343658.txt to DOTA format.
# Converted 8408381_3448224.txt to DOTA format.
# Converted 8391870_3434466.txt to DOTA format.
# Converted 8477174_3434466.txt to DOTA format.
# Converted 8606506_3230837.txt to DOTA format.
# Converted 8496436_3481245.txt to DOTA format.
# Converted 8523954_3280369.txt to DOTA format.
# Converted 8573485_3478493.txt to DOTA format.
# Converted 8543216_3439969.txt to DOTA format.
# Converted 8578988_3563797.txt to DOTA format.
# Converted 8532209_3302382.txt to DOTA format.
# Converted 8488181_3305134.txt to DOTA format.
# Converted 8606506_3252851.txt to DOTA format.
# Converted 8345091_3456480.txt to DOTA format.
# Converted 8578988_3552790.txt to DOTA format.
# Converted 8477174_3233589.txt to DOTA format.
# Converted 8504691_3448224.txt to DOTA format.
# Converted 8309318_3450976.txt to DOTA format.
# Converted 8479926_3431714.txt to DOTA format.
# Converted 8444153_3393190.txt to DOTA format.
# Converted 8455160_3368424.txt to DOTA format.
# Converted 8540464_3467486.txt to DOTA format.
# Converted 8452408_3362921.txt to DOTA format.
# Converted 8386367_3439969.txt to DOTA format.
# Converted 8570733_3566549.txt to DOTA format.
# Converted 8578988_3412452.txt to DOTA format.
# Converted 8435898_3464735.txt to DOTA format.
# Converted 8570733_3470238.txt to DOTA format.
# Converted 8565230_3415204.txt to DOTA format.
# Converted 8479926_3376679.txt to DOTA format.
# Converted 8438650_3431714.txt to DOTA format.
# Converted 8356098_3461983.txt to DOTA format.
# Converted 8578988_3541783.txt to DOTA format.
# Converted 8529457_3483997.txt to DOTA format.
# Converted 8587243_3274865.txt to DOTA format.
# Converted 8474422_3464735.txt to DOTA format.
# Converted 8551471_3442721.txt to DOTA format.
# Converted 8554223_3376679.txt to DOTA format.
# Converted 8510195_3508762.txt to DOTA format.
# Converted 8570733_3448224.txt to DOTA format.
# Converted 8578988_3266610.txt to DOTA format.
# Converted 8515698_3357417.txt to DOTA format.
# Converted 8482678_3417955.txt to DOTA format.
# Converted 8411132_3387686.txt to DOTA format.
# Converted 8474422_3406948.txt to DOTA format.
# Converted 8601002_3511514.txt to DOTA format.
# Converted 8435898_3431714.txt to DOTA format.
# Converted 8347843_3456480.txt to DOTA format.
# Converted 8422139_3420707.txt to DOTA format.
# Converted 8554223_3379431.txt to DOTA format.
# Converted 8521202_3258355.txt to DOTA format.
# Converted 8567981_3503259.txt to DOTA format.
# Converted 8471671_3434466.txt to DOTA format.
# Converted 8606506_3250100.txt to DOTA format.
# Converted 8559726_3354665.txt to DOTA format.
# Converted 8617512_3299631.txt to DOTA format.
# Converted 8504691_3489500.txt to DOTA format.
# Converted 8595499_3283120.txt to DOTA format.
# Converted 8598250_3550038.txt to DOTA format.
# Converted 8592747_3511514.txt to DOTA format.
# Converted 8485429_3401445.txt to DOTA format.
# Converted 8408381_3365672.txt to DOTA format.
# Converted 8559726_3404197.txt to DOTA format.
# Converted 8455160_3354665.txt to DOTA format.
# Converted 8554223_3555542.txt to DOTA format.
# Converted 8490933_3426210.txt to DOTA format.
# Converted 8515698_3272113.txt to DOTA format.
# Converted 8452408_3445473.txt to DOTA format.
# Converted 8581740_3503259.txt to DOTA format.
# Converted 8463415_3354665.txt to DOTA format.
# Converted 8471671_3420707.txt to DOTA format.
# Converted 8532209_3445473.txt to DOTA format.
# Converted 8570733_3481245.txt to DOTA format.
# Converted 8518450_3453728.txt to DOTA format.
# Converted 8556974_3360169.txt to DOTA format.
# Converted 8493684_3459231.txt to DOTA format.
# Converted 8603754_3230837.txt to DOTA format.
# Converted 8567981_3387686.txt to DOTA format.
# Converted 8430395_3428962.txt to DOTA format.
# Converted 8532209_3335403.txt to DOTA format.
# Converted 8317574_3467486.txt to DOTA format.
# Converted 8554223_3431714.txt to DOTA format.
# Converted 8576236_3550038.txt to DOTA format.
# Converted 8562478_3365672.txt to DOTA format.
# Converted 8416636_3417955.txt to DOTA format.
# Converted 8556974_3613328.txt to DOTA format.
# Converted 8350594_3437217.txt to DOTA format.
# Converted 8477174_3384934.txt to DOTA format.
# Converted 8584492_3272113.txt to DOTA format.
# Converted 8490933_3439969.txt to DOTA format.
# Converted 8521202_3382183.txt to DOTA format.
# Converted 8617512_3291376.txt to DOTA format.
# Converted 8537712_3343658.txt to DOTA format.
# Converted 8620264_3299631.txt to DOTA format.
# Converted 8413884_3401445.txt to DOTA format.
# Converted 8545967_3514266.txt to DOTA format.
# Converted 8534960_3318893.txt to DOTA format.
# Converted 8507443_3346410.txt to DOTA format.
# Converted 8463415_3241844.txt to DOTA format.
# Converted 8400126_3448224.txt to DOTA format.
# Converted 8595499_3519769.txt to DOTA format.
# Converted 8358850_3475742.txt to DOTA format.
# Converted 8589995_3511514.txt to DOTA format.
# Converted 8565230_3365672.txt to DOTA format.
# Converted 8342339_3431714.txt to DOTA format.
# Converted 8537712_3357417.txt to DOTA format.
# Converted 8510195_3470238.txt to DOTA format.
# Converted 8474422_3269362.txt to DOTA format.
# Converted 8595499_3233589.txt to DOTA format.
# Converted 8477174_3442721.txt to DOTA format.
# Converted 8490933_3340907.txt to DOTA format.
# Converted 8584492_3269362.txt to DOTA format.
# Converted 8576236_3360169.txt to DOTA format.
# Converted 8606506_3522521.txt to DOTA format.
# Converted 8507443_3354665.txt to DOTA format.
# Converted 8441402_3382183.txt to DOTA format.
# Converted 8314822_3470238.txt to DOTA format.
# Converted 8518450_3269362.txt to DOTA format.
# Converted 8537712_3346410.txt to DOTA format.
# Converted 8345091_3481245.txt to DOTA format.
# Converted 8548719_3489500.txt to DOTA format.
# Converted 8474422_3398693.txt to DOTA format.
# Converted 8334084_3442721.txt to DOTA format.
# Converted 8565230_3214327.txt to DOTA format.
# Converted 8441402_3404197.txt to DOTA format.
# Converted 8609257_3522521.txt to DOTA format.
# Converted 8358850_3431714.txt to DOTA format.
# Converted 8402877_3445473.txt to DOTA format.
# Converted 8474422_3233589.txt to DOTA format.
# Converted 8501940_3467486.txt to DOTA format.
# Converted 8501940_3404197.txt to DOTA format.
# Converted 8320325_3448224.txt to DOTA format.
# Converted 8463415_3362921.txt to DOTA format.
# Converted 8493684_3423459.txt to DOTA format.
# Converted 8556974_3351914.txt to DOTA format.
# Converted 8540464_3354665.txt to DOTA format.
# Converted 8323077_3472990.txt to DOTA format.
# Converted 8455160_3437217.txt to DOTA format.
# Converted 8466167_3384934.txt to DOTA format.
# Converted 8490933_3354665.txt to DOTA format.
# Converted 8433146_3417955.txt to DOTA format.
# Converted 8479926_3310638.txt to DOTA format.
# Converted 8422139_3362921.txt to DOTA format.
# Converted 8303815_3428962.txt to DOTA format.
# Converted 8576236_3577556.txt to DOTA format.
# Converted 8485429_3283120.txt to DOTA format.
# Converted 8576236_3437217.txt to DOTA format.
# Converted 8314822_3475742.txt to DOTA format.
# Converted 8482678_3456480.txt to DOTA format.
# Converted 8595499_3555542.txt to DOTA format.
# Converted 8595499_3503259.txt to DOTA format.
# Converted 8430395_3417955.txt to DOTA format.
# Converted 8584492_3266610.txt to DOTA format.
# Converted 8515698_3508762.txt to DOTA format.
# Converted 8521202_3439969.txt to DOTA format.
# Converted 8339587_3461983.txt to DOTA format.
# Converted 8504691_3346410.txt to DOTA format.
# Converted 8342339_3434466.txt to DOTA format.
# Converted 8534960_3453728.txt to DOTA format.
# Converted 8620264_3244596.txt to DOTA format.
# Converted 8411132_3368424.txt to DOTA format.
# Converted 8468919_3244596.txt to DOTA format.
# Converted 8496436_3379431.txt to DOTA format.
# Converted 8518450_3478493.txt to DOTA format.
# Converted 8515698_3486749.txt to DOTA format.
# Converted 8526705_3296879.txt to DOTA format.
# Converted 8606506_3519769.txt to DOTA format.
# Converted 8534960_3439969.txt to DOTA format.
# Converted 8367105_3464735.txt to DOTA format.
# Converted 8446905_3340907.txt to DOTA format.
# Converted 8339587_3450976.txt to DOTA format.
# Converted 8581740_3261106.txt to DOTA format.
# Converted 8490933_3376679.txt to DOTA format.
# Converted 8430395_3379431.txt to DOTA format.
# Converted 8584492_3511514.txt to DOTA format.
# Converted 8441402_3428962.txt to DOTA format.
# Converted 8567981_3572052.txt to DOTA format.
# Converted 8614761_3285872.txt to DOTA format.
# Converted 8490933_3406948.txt to DOTA format.
# Converted 8449657_3448224.txt to DOTA format.
# Converted 8589995_3552790.txt to DOTA format.
# Converted 8625768_3247348.txt to DOTA format.
# Converted 8601002_3517018.txt to DOTA format.
# Converted 8438650_3472990.txt to DOTA format.
# Converted 8601002_3250100.txt to DOTA format.
# Converted 8556974_3329900.txt to DOTA format.
# Converted 8512947_3489500.txt to DOTA format.
# Converted 8452408_3395941.txt to DOTA format.
# Converted 8479926_3467486.txt to DOTA format.
# Converted 8468919_3406948.txt to DOTA format.
# Converted 8601002_3528025.txt to DOTA format.
# Converted 8570733_3360169.txt to DOTA format.
# Converted 8521202_3255603.txt to DOTA format.
# Converted 8452408_3437217.txt to DOTA format.
# Converted 8556974_3404197.txt to DOTA format.
# Converted 8554223_3398693.txt to DOTA format.
# Converted 8529457_3426210.txt to DOTA format.
# Converted 8526705_3398693.txt to DOTA format.
# Converted 8488181_3261106.txt to DOTA format.
# Converted 8433146_3431714.txt to DOTA format.
# Converted 8446905_3459231.txt to DOTA format.
# Converted 8534960_3332652.txt to DOTA format.
# Converted 8581740_3382183.txt to DOTA format.
# Converted 8482678_3351914.txt to DOTA format.
# Converted 8548719_3445473.txt to DOTA format.
# Converted 8537712_3327148.txt to DOTA format.
# Converted 8523954_3412452.txt to DOTA format.
# Converted 8435898_3351914.txt to DOTA format.
# Converted 8529457_3417955.txt to DOTA format.
# Converted 8482678_3283120.txt to DOTA format.
# Converted 8507443_3349162.txt to DOTA format.
# Converted 8353346_3475742.txt to DOTA format.
# Converted 8565230_3398693.txt to DOTA format.
# Converted 8466167_3255603.txt to DOTA format.
# Converted 8598250_3233589.txt to DOTA format.
# Converted 8521202_3376679.txt to DOTA format.
# Converted 8545967_3395941.txt to DOTA format.
# Converted 8518450_3360169.txt to DOTA format.
# Converted 8562478_3349162.txt to DOTA format.
# Converted 8510195_3453728.txt to DOTA format.
# Converted 8441402_3379431.txt to DOTA format.
# Converted 8548719_3376679.txt to DOTA format.
# Converted 8603754_3258355.txt to DOTA format.
# Converted 8435898_3382183.txt to DOTA format.
# Converted 8614761_3241844.txt to DOTA format.
# Converted 8556974_3489500.txt to DOTA format.
# Converted 8551471_3376679.txt to DOTA format.
# Converted 8488181_3404197.txt to DOTA format.
# Converted 8345091_3439969.txt to DOTA format.
# Converted 8529457_3470238.txt to DOTA format.
# Converted 8543216_3412452.txt to DOTA format.
# Converted 8466167_3354665.txt to DOTA format.
# Converted 8570733_3450976.txt to DOTA format.
# Converted 8438650_3428962.txt to DOTA format.
# Converted 8452408_3439969.txt to DOTA format.
# Converted 8625768_3244596.txt to DOTA format.
# Converted 8424891_3415204.txt to DOTA format.
# Converted 8545967_3398693.txt to DOTA format.
# Converted 8413884_3467486.txt to DOTA format.
# Converted 8471671_3461983.txt to DOTA format.
# Converted 8567981_3382183.txt to DOTA format.
# Converted 8603754_3536280.txt to DOTA format.
# Converted 8419388_3368424.txt to DOTA format.
# Converted 8510195_3357417.txt to DOTA format.
# Converted 8526705_3415204.txt to DOTA format.
# Converted 8424891_3417955.txt to DOTA format.
# Converted 8562478_3453728.txt to DOTA format.
# Converted 8493684_3481245.txt to DOTA format.
# Converted 8570733_3478493.txt to DOTA format.
# Converted 8529457_3401445.txt to DOTA format.
# Converted 8614761_3269362.txt to DOTA format.
# Converted 8545967_3324396.txt to DOTA format.
# Converted 8559726_3362921.txt to DOTA format.
# Converted 8551471_3362921.txt to DOTA format.
# Converted 8336836_3464735.txt to DOTA format.
# Converted 8595499_3550038.txt to DOTA format.
# Converted 8576236_3569301.txt to DOTA format.
# Converted 8537712_3332652.txt to DOTA format.
# Converted 8438650_3373928.txt to DOTA format.
# Converted 8595499_3230837.txt to DOTA format.
# Converted 8570733_3393190.txt to DOTA format.
# Converted 8383615_3415204.txt to DOTA format.
# Converted 8617512_3272113.txt to DOTA format.
# Converted 8532209_3472990.txt to DOTA format.
# Converted 8507443_3307886.txt to DOTA format.
# Converted 8559726_3489500.txt to DOTA format.
# Converted 8603754_3285872.txt to DOTA format.
# Converted 8523954_3274865.txt to DOTA format.
# Converted 8512947_3406948.txt to DOTA format.
# Converted 8540464_3338155.txt to DOTA format.
# Converted 8510195_3338155.txt to DOTA format.
# Converted 8477174_3437217.txt to DOTA format.
# Converted 8606506_3283120.txt to DOTA format.
# Converted 8460664_3450976.txt to DOTA format.
# Converted 8518450_3379431.txt to DOTA format.
# Converted 8435898_3426210.txt to DOTA format.
# Converted 8391870_3442721.txt to DOTA format.
# Converted 8576236_3261106.txt to DOTA format.
# Converted 8449657_3390438.txt to DOTA format.
# Converted 8581740_3390438.txt to DOTA format.
# Converted 8545967_3321645.txt to DOTA format.
# Converted 8411132_3365672.txt to DOTA format.
# Converted 8477174_3401445.txt to DOTA format.
# Converted 8413884_3379431.txt to DOTA format.
# Converted 8529457_3318893.txt to DOTA format.
# Converted 8570733_3442721.txt to DOTA format.
# Converted 8526705_3387686.txt to DOTA format.
# Converted 8457912_3423459.txt to DOTA format.
# Converted 8507443_3340907.txt to DOTA format.
# Converted 8457912_3379431.txt to DOTA format.
# Converted 8394622_3459231.txt to DOTA format.
# Converted 8559726_3357417.txt to DOTA format.
# Converted 8490933_3434466.txt to DOTA format.
# Converted 8545967_3327148.txt to DOTA format.
# Converted 8427643_3417955.txt to DOTA format.
# Converted 8430395_3423459.txt to DOTA format.
# Converted 8584492_3236341.txt to DOTA format.
# Converted 8336836_3475742.txt to DOTA format.
# Converted 8578988_3288624.txt to DOTA format.
# Converted 8460664_3461983.txt to DOTA format.
# Converted 8556974_3472990.txt to DOTA format.
# Converted 8501940_3401445.txt to DOTA format.
# Converted 8523954_3486749.txt to DOTA format.
# Converted 8551471_3351914.txt to DOTA format.
# Converted 8391870_3439969.txt to DOTA format.
# Converted 8460664_3467486.txt to DOTA format.
# Converted 8402877_3448224.txt to DOTA format.
# Converted 8449657_3379431.txt to DOTA format.
# Converted 8612009_3277617.txt to DOTA format.
# Converted 8573485_3481245.txt to DOTA format.
# Converted 8504691_3299631.txt to DOTA format.
# Converted 8521202_3272113.txt to DOTA format.
# Converted 8510195_3511514.txt to DOTA format.
# Converted 8595499_3250100.txt to DOTA format.
# Converted 8485429_3288624.txt to DOTA format.
# Converted 8482678_3335403.txt to DOTA format.
# Converted 8548719_3313389.txt to DOTA format.
# Converted 8350594_3431714.txt to DOTA format.
# Converted 8413884_3382183.txt to DOTA format.
# Converted 8545967_3329900.txt to DOTA format.
# Converted 8567981_3481245.txt to DOTA format.
# Converted 8603754_3241844.txt to DOTA format.
# Converted 8510195_3382183.txt to DOTA format.
# Converted 8419388_3390438.txt to DOTA format.
# Converted 8510195_3379431.txt to DOTA format.
# Converted 8598250_3241844.txt to DOTA format.
# Converted 8474422_3291376.txt to DOTA format.
# Converted 8581740_3572052.txt to DOTA format.
# Converted 8419388_3412452.txt to DOTA format.
# Converted 8499188_3384934.txt to DOTA format.
# Converted 8623016_3255603.txt to DOTA format.
# Converted 8567981_3483997.txt to DOTA format.
# Converted 8485429_3445473.txt to DOTA format.
# Converted 8526705_3277617.txt to DOTA format.
# Converted 8548719_3346410.txt to DOTA format.
# Converted 8356098_3464735.txt to DOTA format.
# Converted 8565230_3409700.txt to DOTA format.
# Converted 8584492_3263858.txt to DOTA format.
# Converted 8545967_3442721.txt to DOTA format.
# Converted 8567981_3412452.txt to DOTA format.
# Converted 8496436_3483997.txt to DOTA format.
# Converted 8518450_3508762.txt to DOTA format.
# Converted 8331332_3495004.txt to DOTA format.
# Converted 8353346_3439969.txt to DOTA format.
# Converted 8457912_3448224.txt to DOTA format.
# Converted 8452408_3401445.txt to DOTA format.
# Converted 8521202_3379431.txt to DOTA format.
# Converted 8523954_3332652.txt to DOTA format.
# Converted 8545967_3555542.txt to DOTA format.
# Converted 8347843_3434466.txt to DOTA format.
# Converted 8556974_3475742.txt to DOTA format.
# Converted 8518450_3459231.txt to DOTA format.
# Converted 8609257_3236341.txt to DOTA format.
# Converted 8543216_3324396.txt to DOTA format.
# Converted 8504691_3351914.txt to DOTA format.
# Converted 8490933_3478493.txt to DOTA format.
# Converted 8532209_3329900.txt to DOTA format.
# Converted 8562478_3472990.txt to DOTA format.
# Converted 8504691_3288624.txt to DOTA format.
# Converted 8540464_3335403.txt to DOTA format.
# Converted 8317574_3470238.txt to DOTA format.
# Converted 8518450_3382183.txt to DOTA format.
# Converted 8303815_3431714.txt to DOTA format.
# Converted 8543216_3338155.txt to DOTA format.
# Converted 8441402_3384934.txt to DOTA format.
# Converted 8482678_3280369.txt to DOTA format.
# Converted 8620264_3255603.txt to DOTA format.
# Converted 8601002_3230837.txt to DOTA format.
# Converted 8584492_3552790.txt to DOTA format.
# Converted 8540464_3417955.txt to DOTA format.
# Converted 8543216_3318893.txt to DOTA format.
# Converted 8323077_3431714.txt to DOTA format.
# Converted 8466167_3379431.txt to DOTA format.
# Converted 8479926_3266610.txt to DOTA format.
# Converted 8601002_3236341.txt to DOTA format.
# Converted 8438650_3384934.txt to DOTA format.
# Converted 8320325_3467486.txt to DOTA format.
# Converted 8507443_3338155.txt to DOTA format.
# Converted 8551471_3321645.txt to DOTA format.
# Converted 8534960_3448224.txt to DOTA format.
# Converted 8540464_3387686.txt to DOTA format.
# Converted 8441402_3373928.txt to DOTA format.
# Converted 8562478_3519769.txt to DOTA format.
# Converted 8389119_3434466.txt to DOTA format.
# Converted 8609257_3277617.txt to DOTA format.
# Converted 8510195_3489500.txt to DOTA format.
# Converted 8587243_3272113.txt to DOTA format.
# Converted 8537712_3338155.txt to DOTA format.
# Converted 8433146_3428962.txt to DOTA format.
# Converted 8551471_3324396.txt to DOTA format.
# Converted 8617512_3274865.txt to DOTA format.
# Converted 8496436_3423459.txt to DOTA format.
# Converted 8446905_3426210.txt to DOTA format.
# Converted 8551471_3401445.txt to DOTA format.
# Converted 8507443_3467486.txt to DOTA format.
# Converted 8501940_3406948.txt to DOTA format.
# Converted 8460664_3448224.txt to DOTA format.
# Converted 8518450_3470238.txt to DOTA format.
# Converted 8570733_3558294.txt to DOTA format.
# Converted 8433146_3448224.txt to DOTA format.
# Converted 8601002_3285872.txt to DOTA format.
# Converted 8534960_3450976.txt to DOTA format.
# Converted 8496436_3376679.txt to DOTA format.
# Converted 8543216_3357417.txt to DOTA format.
# Converted 8353346_3434466.txt to DOTA format.
# Converted 8523954_3481245.txt to DOTA format.
# Converted 8386367_3442721.txt to DOTA format.
# Converted 8543216_3332652.txt to DOTA format.
# Converted 8570733_3495004.txt to DOTA format.
# Converted 8576236_3263858.txt to DOTA format.
# Converted 8573485_3558294.txt to DOTA format.
# Converted 8554223_3415204.txt to DOTA format.
# Converted 8350594_3483997.txt to DOTA format.
# Converted 8493684_3508762.txt to DOTA format.
# Converted 8587243_3511514.txt to DOTA format.
# Converted 8551471_3445473.txt to DOTA format.
# Converted 8562478_3450976.txt to DOTA format.
# Converted 8529457_3390438.txt to DOTA format.
# Converted 8356098_3456480.txt to DOTA format.
# Converted 8545967_3415204.txt to DOTA format.
# Converted 8474422_3357417.txt to DOTA format.
# Converted 8342339_3483997.txt to DOTA format.
# Converted 8612009_3302382.txt to DOTA format.
# Converted 8559726_3450976.txt to DOTA format.
# Converted 8515698_3495004.txt to DOTA format.
# Converted 8490933_3335403.txt to DOTA format.
# Converted 8518450_3371176.txt to DOTA format.
# Converted 8523954_3426210.txt to DOTA format.
# Converted 8595499_3514266.txt to DOTA format.
# Converted 8466167_3450976.txt to DOTA format.
# Converted 8529457_3415204.txt to DOTA format.
# Converted 8358850_3434466.txt to DOTA format.
# Converted 8537712_3415204.txt to DOTA format.
# Converted 8556974_3365672.txt to DOTA format.
# Converted 8584492_3536280.txt to DOTA format.
# Converted 8474422_3442721.txt to DOTA format.
# Converted 8562478_3431714.txt to DOTA format.
# Converted 8345091_3437217.txt to DOTA format.
# Converted 8490933_3401445.txt to DOTA format.
# Converted 8565230_3357417.txt to DOTA format.
# Converted 8573485_3563797.txt to DOTA format.
# Converted 8466167_3351914.txt to DOTA format.
# Converted 8446905_3373928.txt to DOTA format.
# Converted 8565230_3500507.txt to DOTA format.
# Converted 8543216_3456480.txt to DOTA format.
# Converted 8518450_3373928.txt to DOTA format.
# Converted 8504691_3390438.txt to DOTA format.
# Converted 8584492_3561045.txt to DOTA format.
# Converted 8430395_3442721.txt to DOTA format.
# Converted 8532209_3332652.txt to DOTA format.
# Converted 8493684_3338155.txt to DOTA format.
# Converted 8312070_3437217.txt to DOTA format.
# Converted 8512947_3327148.txt to DOTA format.
# Converted 8576236_3574804.txt to DOTA format.
# Converted 8314822_3492252.txt to DOTA format.
# Converted 8567981_3547287.txt to DOTA format.
# Converted 8543216_3365672.txt to DOTA format.
# Converted 8567981_3395941.txt to DOTA format.
# Converted 8562478_3544535.txt to DOTA format.
# Converted 8479926_3296879.txt to DOTA format.
# Converted 8584492_3489500.txt to DOTA format.
# Converted 8565230_3547287.txt to DOTA format.
# Converted 8614761_3296879.txt to DOTA format.
# Converted 8534960_3483997.txt to DOTA format.
# Converted 8477174_3387686.txt to DOTA format.
# Converted 8358850_3459231.txt to DOTA format.
# Converted 8345091_3478493.txt to DOTA format.
# Converted 8510195_3327148.txt to DOTA format.
# Converted 8614761_3283120.txt to DOTA format.
# Converted 8562478_3613328.txt to DOTA format.
# Converted 8567981_3384934.txt to DOTA format.
# Converted 8435898_3450976.txt to DOTA format.
# Converted 8471671_3456480.txt to DOTA format.
# Converted 8477174_3305134.txt to DOTA format.
# Converted 8479926_3302382.txt to DOTA format.
# Converted 8592747_3252851.txt to DOTA format.
# Converted 8565230_3387686.txt to DOTA format.
# Converted 8567981_3533528.txt to DOTA format.
# Converted 8578988_3263858.txt to DOTA format.
# Converted 8570733_3412452.txt to DOTA format.
# Converted 8504691_3296879.txt to DOTA format.
# Converted 8501940_3384934.txt to DOTA format.
# Converted 8518450_3258355.txt to DOTA format.
# Converted 8540464_3536280.txt to DOTA format.
# Converted 8468919_3464735.txt to DOTA format.
# Converted 8482678_3415204.txt to DOTA format.
# Converted 8565230_3544535.txt to DOTA format.
# Converted 8570733_3561045.txt to DOTA format.
# Converted 8545967_3288624.txt to DOTA format.
# Converted 8488181_3340907.txt to DOTA format.
# Converted 8584492_3547287.txt to DOTA format.
# Converted 8347843_3439969.txt to DOTA format.
# Converted 8320325_3453728.txt to DOTA format.
# Converted 8496436_3390438.txt to DOTA format.
# Converted 8595499_3241844.txt to DOTA format.
# Converted 8474422_3288624.txt to DOTA format.
# Converted 8375360_3409700.txt to DOTA format.
# Converted 8567981_3569301.txt to DOTA format.
# Converted 8342339_3439969.txt to DOTA format.
# Converted 8474422_3241844.txt to DOTA format.

# %%
print(len(os.listdir(input_folder)))
print(len(os.listdir(output_folder)))
# Out:
# 586
# 586
