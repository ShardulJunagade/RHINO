# %%
import os

class_mapping = {0: "CFCBK", 1: "FCBK", 2: "Zigzag"}
image_width = 640
image_height = 640

def convert_to_dota_format(input_path, output_path):
	with open(input_path, "r") as infile, open(output_path, "w") as outfile:
		for line in infile:
			# Split the annotation line into its components
			values = line.strip().split()
			class_id = int(values[0])  # First value is the class ID
			coordinates = list(map(float, values[1:9]))  # Next 8 values are normalized coordinates

			# Denormalize the coordinates to absolute pixel values
			denormalized_coords = [
				int(coordinates[i] * (image_width if i % 2 == 0 else image_height)) + 0.0
				for i in range(8)
			]

			# Retrieve the class name from the mapping
			class_name = class_mapping.get(class_id, "UNKNOWN")

			# Format the line in DOTA format
			dota_line = " ".join(map(str, denormalized_coords)) + f" {class_name} 0\n"
			outfile.write(dota_line)

def process_folder(input_folder, output_folder):
	os.makedirs(output_folder, exist_ok=True)
	for file_name in os.listdir(input_folder):
		if file_name.endswith(".txt"):
			input_path = os.path.join(input_folder, file_name)
			output_path = os.path.join(output_folder, file_name)
			convert_to_dota_format(input_path, output_path)
			print(f"Converted {file_name} to DOTA format.")

# %%
# convert_to_dota_format("./test.txt", "./test_dota.txt")

# %%
input_folder = "../data/zeel/m0_obb_without_empty_val/labels"
output_folder = "../data/m0/val/annfiles"
process_folder(input_folder, output_folder)
# Out:
# Converted 8566453_3353442.txt to DOTA format.
# Converted 8996640_3085607.txt to DOTA format.
# Converted 8615984_3295656.txt to DOTA format.
# Converted 8599473_3372705.txt to DOTA format.
# Converted 8563701_3347939.txt to DOTA format.
# Converted 9029661_3121380.txt to DOTA format.
# Converted 8610480_3342435.txt to DOTA format.
# Converted 8632494_3298408.txt to DOTA format.
# Converted 9013151_3077352.txt to DOTA format.
# Converted 8629742_3323173.txt to DOTA format.
# Converted 9002144_3115876.txt to DOTA format.
# Converted 9026909_3082855.txt to DOTA format.
# Converted 9004895_3077352.txt to DOTA format.
# Converted 8613232_3287401.txt to DOTA format.
# Converted 8090708_2648693.txt to DOTA format.
# Converted 8985633_3137890.txt to DOTA format.
# Converted 8637998_3345187.txt to DOTA format.
# Converted 9007647_3143393.txt to DOTA format.
# Converted 9021406_3115876.txt to DOTA format.
# Converted 9021406_3082855.txt to DOTA format.
# Converted 8615984_3281897.txt to DOTA format.
# Converted 8637998_3309415.txt to DOTA format.
# Converted 8079702_2648693.txt to DOTA format.
# Converted 8560949_3372705.txt to DOTA format.
# Converted 8596722_3369953.txt to DOTA format.
# Converted 8604977_3279146.txt to DOTA format.
# Converted 9024157_3118628.txt to DOTA format.
# Converted 8599473_3364449.txt to DOTA format.
# Converted 8082453_2656948.txt to DOTA format.
# Converted 9018654_3118628.txt to DOTA format.
# Converted 8591218_3358946.txt to DOTA format.
# Converted 9004895_3135138.txt to DOTA format.
# Converted 8558197_3361698.txt to DOTA format.
# Converted 8574708_3358946.txt to DOTA format.
# Converted 8068695_2618424.txt to DOTA format.
# Converted 9002144_3107621.txt to DOTA format.
# Converted 9785165_2520585.txt to DOTA format.
# Converted 8618735_3350691.txt to DOTA format.
# Converted 8637998_3361698.txt to DOTA format.
# Converted 8093460_2648693.txt to DOTA format.
# Converted 8991137_3080104.txt to DOTA format.
# Converted 8613232_3367201.txt to DOTA format.
# Converted 8629742_3350691.txt to DOTA format.
# Converted 8560949_3342435.txt to DOTA format.
# Converted 8621487_3372705.txt to DOTA format.
# Converted 9021406_3080104.txt to DOTA format.
# Converted 8615984_3276394.txt to DOTA format.
# Converted 9024157_3135138.txt to DOTA format.
# Converted 9035164_3102117.txt to DOTA format.
# Converted 9037916_3088359.txt to DOTA format.
# Converted 8613232_3361698.txt to DOTA format.
# Converted 8093460_2621176.txt to DOTA format.
# Converted 9032413_3124131.txt to DOTA format.
# Converted 8577459_3356194.txt to DOTA format.
# Converted 8613232_3279146.txt to DOTA format.
# Converted 8079702_2654196.txt to DOTA format.
# Converted 8602225_3356194.txt to DOTA format.
# Converted 9004895_3146145.txt to DOTA format.
# Converted 8615984_3356194.txt to DOTA format.
# Converted 9035164_3088359.txt to DOTA format.
# Converted 8637998_3290153.txt to DOTA format.
# Converted 8621487_3350691.txt to DOTA format.
# Converted 8607729_3350691.txt to DOTA format.
# Converted 9787916_2542598.txt to DOTA format.
# Converted 8068695_2632183.txt to DOTA format.
# Converted 8613232_3284649.txt to DOTA format.
# Converted 8613232_3356194.txt to DOTA format.
# Converted 8635246_3290153.txt to DOTA format.
# Converted 8621487_3358946.txt to DOTA format.
# Converted 8999392_3082855.txt to DOTA format.
# Converted 9007647_3140642.txt to DOTA format.
# Converted 8624239_3342435.txt to DOTA format.
# Converted 8563701_3367201.txt to DOTA format.
# Converted 9035164_3077352.txt to DOTA format.
# Converted 8563701_3353442.txt to DOTA format.
# Converted 8093460_2634934.txt to DOTA format.
# Converted 9782413_2531591.txt to DOTA format.
# Converted 9013151_3115876.txt to DOTA format.
# Converted 8640749_3309415.txt to DOTA format.
# Converted 8993888_3085607.txt to DOTA format.
# Converted 8624239_3356194.txt to DOTA format.
# Converted 8563701_3342435.txt to DOTA format.
# Converted 8637998_3298408.txt to DOTA format.
# Converted 9024157_3085607.txt to DOTA format.

# %%
print(len(os.listdir(input_folder)))
print(len(os.listdir(output_folder)))
# Out:
# 84
# 84

# %%
input_folder = "../data/zeel/m0_obb_without_empty_train/labels"
output_folder = "../data/m0/train/annfiles"
process_folder(input_folder, output_folder)
# Out:
# Converted 8996640_3082855.txt to DOTA format.
# Converted 8607729_3364449.txt to DOTA format.
# Converted 8558197_3372705.txt to DOTA format.
# Converted 9007647_3088359.txt to DOTA format.
# Converted 9013151_3088359.txt to DOTA format.
# Converted 8615984_3292904.txt to DOTA format.
# Converted 8635246_3356194.txt to DOTA format.
# Converted 8632494_3279146.txt to DOTA format.
# Converted 9035164_3107621.txt to DOTA format.
# Converted 8101715_2643190.txt to DOTA format.
# Converted 8635246_3295656.txt to DOTA format.
# Converted 9037916_3107621.txt to DOTA format.
# Converted 8563701_3345187.txt to DOTA format.
# Converted 8613232_3353442.txt to DOTA format.
# Converted 8560949_3331429.txt to DOTA format.
# Converted 8985633_3140642.txt to DOTA format.
# Converted 9007647_3118628.txt to DOTA format.
# Converted 9007647_3124131.txt to DOTA format.
# Converted 8591218_3361698.txt to DOTA format.
# Converted 8993888_3082855.txt to DOTA format.
# Converted 8566453_3347939.txt to DOTA format.
# Converted 9787916_2523336.txt to DOTA format.
# Converted 8629742_3356194.txt to DOTA format.
# Converted 8988385_3143393.txt to DOTA format.
# Converted 9021406_3091111.txt to DOTA format.
# Converted 8632494_3347939.txt to DOTA format.
# Converted 8615984_3298408.txt to DOTA format.
# Converted 9032413_3110373.txt to DOTA format.
# Converted 8621487_3281897.txt to DOTA format.
# Converted 8607729_3347939.txt to DOTA format.
# Converted 8607729_3358946.txt to DOTA format.
# Converted 8065943_2618424.txt to DOTA format.
# Converted 8615984_3367201.txt to DOTA format.
# Converted 9018654_3129635.txt to DOTA format.
# Converted 9793420_2537095.txt to DOTA format.
# Converted 9037916_3140642.txt to DOTA format.
# Converted 9002144_3140642.txt to DOTA format.
# Converted 9787916_2520585.txt to DOTA format.
# Converted 8988385_3140642.txt to DOTA format.
# Converted 8626991_3356194.txt to DOTA format.
# Converted 9021406_3113124.txt to DOTA format.
# Converted 8599473_3361698.txt to DOTA format.
# Converted 9785165_2542598.txt to DOTA format.
# Converted 9007647_3085607.txt to DOTA format.
# Converted 9040668_3118628.txt to DOTA format.
# Converted 9040668_3102117.txt to DOTA format.
# Converted 8999392_3085607.txt to DOTA format.
# Converted 8640749_3281897.txt to DOTA format.
# Converted 8558197_3356194.txt to DOTA format.
# Converted 9787916_2526088.txt to DOTA format.
# Converted 8082453_2654196.txt to DOTA format.
# Converted 8065943_2615672.txt to DOTA format.
# Converted 8604977_3347939.txt to DOTA format.
# Converted 9024157_3096614.txt to DOTA format.
# Converted 8982881_3146145.txt to DOTA format.
# Converted 9040668_3107621.txt to DOTA format.
# Converted 9032413_3107621.txt to DOTA format.
# Converted 9024157_3082855.txt to DOTA format.
# Converted 8604977_3350691.txt to DOTA format.
# Converted 8996640_3140642.txt to DOTA format.
# Converted 8618735_3369953.txt to DOTA format.
# Converted 9040668_3093862.txt to DOTA format.
# Converted 9021406_3085607.txt to DOTA format.
# Converted 9035164_3096614.txt to DOTA format.
# Converted 9024157_3113124.txt to DOTA format.
# Converted 9021406_3135138.txt to DOTA format.
# Converted 8060439_2626679.txt to DOTA format.
# Converted 8618735_3279146.txt to DOTA format.
# Converted 9776909_2537095.txt to DOTA format.
# Converted 9037916_3085607.txt to DOTA format.
# Converted 9026909_3121380.txt to DOTA format.
# Converted 9785165_2526088.txt to DOTA format.
# Converted 8076950_2656948.txt to DOTA format.
# Converted 8615984_3347939.txt to DOTA format.
# Converted 9790668_2520585.txt to DOTA format.
# Converted 9040668_3129635.txt to DOTA format.
# Converted 8640749_3306663.txt to DOTA format.
# Converted 8558197_3367201.txt to DOTA format.
# Converted 9004895_3080104.txt to DOTA format.
# Converted 9007647_3135138.txt to DOTA format.
# Converted 8621487_3361698.txt to DOTA format.
# Converted 9029661_3107621.txt to DOTA format.
# Converted 9026909_3146145.txt to DOTA format.
# Converted 8621487_3353442.txt to DOTA format.
# Converted 8615984_3369953.txt to DOTA format.
# Converted 8558197_3364449.txt to DOTA format.
# Converted 8577459_3287401.txt to DOTA format.
# Converted 9035164_3104869.txt to DOTA format.
# Converted 8607729_3345187.txt to DOTA format.
# Converted 8982881_3143393.txt to DOTA format.
# Converted 9002144_3137890.txt to DOTA format.
# Converted 9015902_3115876.txt to DOTA format.
# Converted 9032413_3121380.txt to DOTA format.
# Converted 8624239_3350691.txt to DOTA format.
# Converted 8618735_3358946.txt to DOTA format.
# Converted 9021406_3121380.txt to DOTA format.
# Converted 8615984_3358946.txt to DOTA format.
# Converted 8560949_3367201.txt to DOTA format.
# Converted 8563701_3339684.txt to DOTA format.
# Converted 9040668_3115876.txt to DOTA format.
# Converted 8602225_3361698.txt to DOTA format.
# Converted 8071446_2626679.txt to DOTA format.
# Converted 8096212_2629431.txt to DOTA format.
# Converted 9010399_3088359.txt to DOTA format.
# Converted 8618735_3342435.txt to DOTA format.
# Converted 8596722_3372705.txt to DOTA format.
# Converted 9782413_2528840.txt to DOTA format.
# Converted 8618735_3281897.txt to DOTA format.
# Converted 8618735_3290153.txt to DOTA format.
# Converted 8621487_3345187.txt to DOTA format.
# Converted 8604977_3369953.txt to DOTA format.
# Converted 8098964_2623927.txt to DOTA format.
# Converted 9037916_3104869.txt to DOTA format.
# Converted 8999392_3140642.txt to DOTA format.
# Converted 9790668_2526088.txt to DOTA format.
# Converted 9024157_3115876.txt to DOTA format.
# Converted 8982881_3085607.txt to DOTA format.
# Converted 9032413_3126883.txt to DOTA format.
# Converted 9037916_3110373.txt to DOTA format.
# Converted 9785165_2531591.txt to DOTA format.
# Converted 8613232_3345187.txt to DOTA format.
# Converted 8996640_3080104.txt to DOTA format.
# Converted 8626991_3347939.txt to DOTA format.
# Converted 8071446_2623927.txt to DOTA format.
# Converted 9040668_3104869.txt to DOTA format.
# Converted 9032413_3077352.txt to DOTA format.
# Converted 9007647_3126883.txt to DOTA format.
# Converted 8560949_3369953.txt to DOTA format.
# Converted 8637998_3317670.txt to DOTA format.
# Converted 8574708_3361698.txt to DOTA format.
# Converted 8629742_3339684.txt to DOTA format.
# Converted 8624239_3358946.txt to DOTA format.
# Converted 9024157_3099366.txt to DOTA format.
# Converted 8635246_3347939.txt to DOTA format.
# Converted 9793420_2526088.txt to DOTA format.
# Converted 8602225_3358946.txt to DOTA format.
# Converted 8618735_3339684.txt to DOTA format.
# Converted 8076950_2654196.txt to DOTA format.
# Converted 9007647_3129635.txt to DOTA format.
# Converted 9010399_3085607.txt to DOTA format.
# Converted 9024157_3088359.txt to DOTA format.
# Converted 8621487_3279146.txt to DOTA format.
# Converted 9021406_3146145.txt to DOTA format.
# Converted 8065943_2629431.txt to DOTA format.
# Converted 8613232_3364449.txt to DOTA format.
# Converted 8063191_2623927.txt to DOTA format.
# Converted 8618735_3347939.txt to DOTA format.
# Converted 8604977_3353442.txt to DOTA format.
# Converted 8637998_3303911.txt to DOTA format.
# Converted 8615984_3287401.txt to DOTA format.
# Converted 9002144_3085607.txt to DOTA format.
# Converted 9785165_2528840.txt to DOTA format.
# Converted 8560949_3356194.txt to DOTA format.
# Converted 9026909_3143393.txt to DOTA format.
# Converted 8621487_3339684.txt to DOTA format.
# Converted 8993888_3080104.txt to DOTA format.
# Converted 8988385_3146145.txt to DOTA format.
# Converted 9793420_2523336.txt to DOTA format.
# Converted 8613232_3342435.txt to DOTA format.
# Converted 8615984_3279146.txt to DOTA format.
# Converted 9018654_3093862.txt to DOTA format.
# Converted 9037916_3146145.txt to DOTA format.
# Converted 8629742_3317670.txt to DOTA format.
# Converted 8079702_2656948.txt to DOTA format.
# Converted 9029661_3110373.txt to DOTA format.
# Converted 8610480_3276394.txt to DOTA format.
# Converted 9004895_3118628.txt to DOTA format.
# Converted 9007647_3137890.txt to DOTA format.
# Converted 8602225_3367201.txt to DOTA format.
# Converted 8087957_2645941.txt to DOTA format.
# Converted 9015902_3080104.txt to DOTA format.
# Converted 8618735_3372705.txt to DOTA format.
# Converted 9024157_3143393.txt to DOTA format.
# Converted 9776909_2531591.txt to DOTA format.
# Converted 9035164_3110373.txt to DOTA format.
# Converted 8560949_3328677.txt to DOTA format.
# Converted 8615984_3361698.txt to DOTA format.
# Converted 9015902_3077352.txt to DOTA format.
# Converted 9021406_3118628.txt to DOTA format.
# Converted 9782413_2526088.txt to DOTA format.
# Converted 8613232_3347939.txt to DOTA format.
# Converted 9010399_3126883.txt to DOTA format.
# Converted 8613232_3339684.txt to DOTA format.
# Converted 9779661_2528840.txt to DOTA format.
# Converted 8566453_3356194.txt to DOTA format.
# Converted 8621487_3369953.txt to DOTA format.
# Converted 8629742_3353442.txt to DOTA format.
# Converted 8558197_3369953.txt to DOTA format.
# Converted 8577459_3364449.txt to DOTA format.
# Converted 9040668_3110373.txt to DOTA format.
# Converted 8615984_3290153.txt to DOTA format.
# Converted 9018654_3135138.txt to DOTA format.
# Converted 9032413_3091111.txt to DOTA format.
# Converted 8618735_3356194.txt to DOTA format.
# Converted 8599473_3367201.txt to DOTA format.
# Converted 8090708_2626679.txt to DOTA format.
# Converted 9779661_2531591.txt to DOTA format.
# Converted 8618735_3276394.txt to DOTA format.
# Converted 8637998_3347939.txt to DOTA format.
# Converted 8635246_3298408.txt to DOTA format.
# Converted 8982881_3077352.txt to DOTA format.
# Converted 9035164_3091111.txt to DOTA format.
# Converted 9790668_2542598.txt to DOTA format.
# Converted 8991137_3135138.txt to DOTA format.
# Converted 9010399_3082855.txt to DOTA format.
# Converted 9040668_3135138.txt to DOTA format.
# Converted 8618735_3345187.txt to DOTA format.
# Converted 8604977_3367201.txt to DOTA format.
# Converted 8560949_3350691.txt to DOTA format.
# Converted 8618735_3364449.txt to DOTA format.
# Converted 8610480_3369953.txt to DOTA format.
# Converted 8063191_2618424.txt to DOTA format.
# Converted 8604977_3364449.txt to DOTA format.
# Converted 9037916_3135138.txt to DOTA format.
# Converted 8640749_3298408.txt to DOTA format.
# Converted 8610480_3347939.txt to DOTA format.
# Converted 8999392_3077352.txt to DOTA format.
# Converted 9004895_3126883.txt to DOTA format.
# Converted 9040668_3140642.txt to DOTA format.
# Converted 9002144_3077352.txt to DOTA format.
# Converted 9013151_3132387.txt to DOTA format.
# Converted 9793420_2528840.txt to DOTA format.
# Converted 9010399_3129635.txt to DOTA format.
# Converted 9010399_3132387.txt to DOTA format.
# Converted 8621487_3347939.txt to DOTA format.
# Converted 8602225_3353442.txt to DOTA format.
# Converted 8610480_3287401.txt to DOTA format.
# Converted 9029661_3096614.txt to DOTA format.
# Converted 8640749_3301159.txt to DOTA format.
# Converted 8068695_2623927.txt to DOTA format.
# Converted 8999392_3080104.txt to DOTA format.
# Converted 9040668_3137890.txt to DOTA format.
# Converted 8602225_3276394.txt to DOTA format.
# Converted 9021406_3096614.txt to DOTA format.
# Converted 8610480_3339684.txt to DOTA format.
# Converted 8610480_3350691.txt to DOTA format.
# Converted 8602225_3372705.txt to DOTA format.
# Converted 8563701_3369953.txt to DOTA format.
# Converted 9032413_3085607.txt to DOTA format.
# Converted 8988385_3135138.txt to DOTA format.
# Converted 8996640_3088359.txt to DOTA format.
# Converted 8618735_3367201.txt to DOTA format.
# Converted 8604977_3372705.txt to DOTA format.
# Converted 8090708_2645941.txt to DOTA format.
# Converted 8063191_2629431.txt to DOTA format.
# Converted 9793420_2520585.txt to DOTA format.
# Converted 8060439_2629431.txt to DOTA format.
# Converted 8082453_2651445.txt to DOTA format.
# Converted 9024157_3124131.txt to DOTA format.
# Converted 8999392_3102117.txt to DOTA format.
# Converted 8604977_3356194.txt to DOTA format.
# Converted 8599473_3369953.txt to DOTA format.
# Converted 9032413_3088359.txt to DOTA format.
# Converted 8087957_2626679.txt to DOTA format.
# Converted 9035164_3085607.txt to DOTA format.
# Converted 8613232_3301159.txt to DOTA format.
# Converted 9002144_3146145.txt to DOTA format.
# Converted 8982881_3140642.txt to DOTA format.
# Converted 9790668_2523336.txt to DOTA format.
# Converted 9776909_2534343.txt to DOTA format.
# Converted 9029661_3088359.txt to DOTA format.
# Converted 8607729_3281897.txt to DOTA format.
# Converted 9040668_3085607.txt to DOTA format.
# Converted 9002144_3104869.txt to DOTA format.
# Converted 8607729_3279146.txt to DOTA format.
# Converted 9032413_3096614.txt to DOTA format.
# Converted 9021406_3099366.txt to DOTA format.
# Converted 9018654_3113124.txt to DOTA format.
# Converted 8566453_3350691.txt to DOTA format.
# Converted 8563701_3350691.txt to DOTA format.
# Converted 8637998_3314918.txt to DOTA format.
# Converted 8571956_3356194.txt to DOTA format.
# Converted 8993888_3137890.txt to DOTA format.
# Converted 9032413_3104869.txt to DOTA format.
# Converted 8613232_3350691.txt to DOTA format.
# Converted 9013151_3113124.txt to DOTA format.
# Converted 8632494_3356194.txt to DOTA format.
# Converted 9018654_3091111.txt to DOTA format.
# Converted 8093460_2637686.txt to DOTA format.
# Converted 9026909_3110373.txt to DOTA format.
# Converted 8640749_3314918.txt to DOTA format.
# Converted 8090708_2621176.txt to DOTA format.
# Converted 8604977_3358946.txt to DOTA format.
# Converted 8569204_3364449.txt to DOTA format.
# Converted 8566453_3358946.txt to DOTA format.
# Converted 8621487_3356194.txt to DOTA format.
# Converted 9793420_2539847.txt to DOTA format.
# Converted 9010399_3077352.txt to DOTA format.
# Converted 8076950_2648693.txt to DOTA format.
# Converted 8988385_3137890.txt to DOTA format.
# Converted 8615984_3364449.txt to DOTA format.
# Converted 8613232_3358946.txt to DOTA format.
# Converted 9029661_3091111.txt to DOTA format.
# Converted 8615984_3284649.txt to DOTA format.
# Converted 9776909_2539847.txt to DOTA format.
# Converted 9037916_3129635.txt to DOTA format.
# Converted 8985633_3080104.txt to DOTA format.
# Converted 9029661_3137890.txt to DOTA format.
# Converted 8637998_3295656.txt to DOTA format.
# Converted 8637998_3301159.txt to DOTA format.
# Converted 9787916_2548102.txt to DOTA format.
# Converted 8615984_3301159.txt to DOTA format.
# Converted 8613232_3292904.txt to DOTA format.
# Converted 8569204_3356194.txt to DOTA format.
# Converted 9007647_3146145.txt to DOTA format.
# Converted 9021406_3110373.txt to DOTA format.
# Converted 8093460_2629431.txt to DOTA format.
# Converted 8635246_3292904.txt to DOTA format.
# Converted 8613232_3276394.txt to DOTA format.
# Converted 9040668_3088359.txt to DOTA format.
# Converted 8063191_2632183.txt to DOTA format.
# Converted 8098964_2626679.txt to DOTA format.
# Converted 9040668_3099366.txt to DOTA format.
# Converted 9037916_3137890.txt to DOTA format.
# Converted 9037916_3121380.txt to DOTA format.
# Converted 8610480_3345187.txt to DOTA format.
# Converted 9029661_3146145.txt to DOTA format.
# Converted 8635246_3345187.txt to DOTA format.
# Converted 8574708_3356194.txt to DOTA format.
# Converted 8074198_2623927.txt to DOTA format.
# Converted 9037916_3102117.txt to DOTA format.
# Converted 8591218_3356194.txt to DOTA format.
# Converted 8632494_3292904.txt to DOTA format.
# Converted 9035164_3099366.txt to DOTA format.
# Converted 8637998_3292904.txt to DOTA format.
# Converted 9024157_3121380.txt to DOTA format.
# Converted 8602225_3284649.txt to DOTA format.
# Converted 9787916_2545350.txt to DOTA format.
# Converted 8079702_2612920.txt to DOTA format.
# Converted 9035164_3115876.txt to DOTA format.
# Converted 8635246_3350691.txt to DOTA format.
# Converted 8629742_3342435.txt to DOTA format.
# Converted 8558197_3353442.txt to DOTA format.
# Converted 8607729_3367201.txt to DOTA format.
# Converted 8093460_2632183.txt to DOTA format.
# Converted 9002144_3118628.txt to DOTA format.
# Converted 8621487_3342435.txt to DOTA format.
# Converted 9002144_3102117.txt to DOTA format.
# Converted 8635246_3339684.txt to DOTA format.
# Converted 9037916_3099366.txt to DOTA format.
# Converted 8602225_3287401.txt to DOTA format.
# Converted 8632494_3276394.txt to DOTA format.
# Converted 8615984_3342435.txt to DOTA format.
# Converted 8632494_3350691.txt to DOTA format.
# Converted 8079702_2651445.txt to DOTA format.
# Converted 8577459_3358946.txt to DOTA format.
# Converted 8985633_3143393.txt to DOTA format.
# Converted 9021406_3129635.txt to DOTA format.
# Converted 9026909_3107621.txt to DOTA format.
# Converted 9035164_3093862.txt to DOTA format.
# Converted 8566453_3364449.txt to DOTA format.
# Converted 8610480_3358946.txt to DOTA format.
# Converted 9026909_3077352.txt to DOTA format.
# Converted 9018654_3115876.txt to DOTA format.
# Converted 9040668_3113124.txt to DOTA format.
# Converted 8060439_2632183.txt to DOTA format.
# Converted 8577459_3361698.txt to DOTA format.

# %%
print(len(os.listdir(input_folder)))
print(len(os.listdir(output_folder)))
# Out:
# 357
# 357
